# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.stats import describe

sns.set_theme()

# %%
bdi1 = pd.read_excel("data/Period I/BDI.xlsx")
bdi2 = pd.read_excel("data/Period II/BDI.xlsx")

idx1 = pd.read_excel("data/Period I/Uncertainty Indexes.xlsx") 
idx2 = pd.read_excel("data/Period II/Uncertain Indexes.xlsx")

# %%
bdi1
# Out:
#         Time         BDI
# 0    2001.11   855.22727
# 1    2001.11   870.17647
# 2    2002.10   931.31818
# 3    2002.20   959.55000
# 4    2002.30  1064.75000
# ..       ...         ...
# 118  2011.90  1840.40909
# 119  2011.10  2072.47619
# 120  2011.11  1835.31818
# 121  2011.12  1868.82353
# 122  2012.10  1039.38095
#
# [123 rows x 2 columns]

# %%
bdi2
# Out:
#         Time         BDI
# 0    2012.20   702.61905
# 1    2012.30   858.95455
# 2    2012.40  1020.52632
# 3    2012.50  1101.27273
# 4    2012.60   937.42105
# ..       ...         ...
# 126  2022.80  1411.95455
# 127  2022.90  1487.14286
# 128  2022.10  1813.85714
# 129  2022.11  1298.95455
# 130  2022.12  1453.41176
#
# [131 rows x 2 columns]

# %%
idx1
# Out:
#         Time  GEPU_current    GEPU_ppp  美国-Three_Component_Index  \
# 0    2001.11    126.150648  121.680190                       131
# 1    2001.11    107.734812  104.203253                       117
# 2    2002.10    106.974245  105.715560                       117
# 3    2002.20     89.900054   88.641668                        88
# 4    2002.30     78.781740   79.094478                        83
# ..       ...           ...         ...                       ...
# 118  2011.90    190.957718  187.993301                       205
# 119  2011.10    165.130505  170.269630                       160
# 120  2011.11    197.574134  204.322067                       166
# 121  2011.12    181.425466  190.839742                       189
# 122  2012.10    160.907847  167.537829                       178
#
#      美国-News_Based_Policy_Uncert_Index  美国-1. Economic Policy Uncertainty  \
# 0                                  172                         153.501517
# ...

# %%
idx2
# Out:
#         Time  GEPU_current    GEPU_ppp  美国-Three_Component_Index  \
# 0    2012.20    141.622551  147.885446                       150
# 1    2012.30    134.292361  148.068999                       138
# 2    2012.40    126.483872  130.266071                       137
# 3    2012.50    159.535464  164.349088                       159
# 4    2012.60    188.157861  194.856394                       195
# ..       ...           ...         ...                       ...
# 126  2022.80    256.913949  262.792255                       163
# 127  2022.90    280.669847  289.610062                       174
# 128  2022.10    299.774458  307.753749                       177
# 129  2022.11    331.335811  347.730650                       172
# 130  2022.12    260.434961  277.400806                       136
#
#      美国-News_Based_Policy_Uncert_Index  美国-1. Economic Policy Uncertainty  \
# 0                                  119                         100.170604
# ...

# %%
bdi1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    123 non-null    float64
#  1   BDI     123 non-null    float64
# dtypes: float64(2)
# memory usage: 2.1 KB

# %%
bdi2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    131 non-null    float64
#  1   BDI     131 non-null    float64
# dtypes: float64(2)
# memory usage: 2.2 KB

# %%
idx1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Columns: 378 entries, Time to GPRHC_ZAF
# dtypes: float64(371), int64(7)
# memory usage: 363.4 KB

# %%
idx2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Columns: 446 entries, Time to GPRHC_ZAF
# dtypes: float64(441), int64(5)
# memory usage: 456.6 KB

# %%
bdi1 = bdi1.set_index("Time").sort_index()
bdi2 = bdi2.set_index("Time").sort_index()

idx1 = idx1.set_index("Time").sort_index()
idx2 = idx2.set_index("Time").sort_index()

# %% [markdown]
# Time indices are clearly broken due to bad excel formatting, we fix them here

# %%
period1_idx = pd.date_range(
    start="2001-11",
    end="2012-02",
    freq="ME"
)

period2_idx = pd.date_range(
    start="2012-02",
    end="2023-01",
    freq="ME"
)

bdi1.index = period1_idx
bdi2.index = period2_idx

idx1.index = period1_idx
idx2.index = period2_idx

# %%
print(len(idx2.columns.intersection(idx1.columns)))
# period I indices, not a subset of period II
len(idx1.columns)
# Out:
# 345
# 377

# %%
period1_non_english_cols = {(i, col): [c for c in col if ord(c) > 127] for i, col in enumerate(idx1.columns) if not col.isascii()}
period2_non_english_cols = {(i, col): [c for c in col if ord(c) > 127] for i, col in enumerate(idx2.columns) if not col.isascii()}
display(period1_non_english_cols)
period2_non_english_cols
# Out:
# {(2, '美国-Three_Component_Index'): ['美', '国'],
#  (3, '美国-News_Based_Policy_Uncert_Index'): ['美', '国'],
#  (4, '美国-1. Economic Policy Uncertainty'): ['美', '国'],
#  (5, '美国-2. Monetary policy'): ['美', '国'],
#  (6, '美国-Fiscal Policy (Taxes OR Spending)'): ['美', '国'],
#  (7, '美国-3. Taxes'): ['美', '国'],
#  (8, '美国-4. Government spending'): ['美', '国'],
#  (9, '美国-5. Health care'): ['美', '国'],
#  (10, '美国-6. National security'): ['美', '国'],
#  (11, '美国-7. Entitlement programs'): ['美', '国'],
#  (12, '美国-8. Regulation'): ['美', '国'],
#  (13, '美国-Financial Regulation'): ['美', '国'],
#  (14, '美国-9. Trade policy'): ['美', '国'],
#  (15, '美国-10. Sovereign debt, currency crises'): ['美', '国'],
#  (22, '智利-EPU*'): ['智', '利'],
#  (23, '智利-EPUC**'): ['智', '利'],
#  (25, '中国-TPU'): ['中', '国'],
#  (26, '中国-EPU'): ['中', '国'],
#  (27, '哥伦比亚-EU_SA*'): ['哥', '伦', '比', '亚'],
#  (28, '哥伦比亚-EUC_SA'): ['哥', '伦', '比', '亚'],
#  (29, '哥伦比亚-EPU_SA'): ['哥', '伦', '比', '亚'],
#  (30, '哥伦比亚-EPUC_SA'): ['哥', '伦', '比', '亚'],
# ...

# %% [markdown]
# All non-ascii chars are em dash or chinese countries. We'll fix these shortly.

# %%
em_dash_cols_period1 = list(range(220, 229)) + [264]
em_dash_cols_period2 = list(range(218, 227))

# need extra lists as pandas columns are immutable (frozen list)
idx1_cols = list(idx1.columns)
idx2_cols = list(idx2.columns)

for col_idx in em_dash_cols_period1:
    idx1_cols[col_idx] = idx1_cols[col_idx].replace("–", "-")

for col_idx in em_dash_cols_period2:
    idx2_cols[col_idx] = idx2_cols[col_idx].replace("–", "-")

idx1.columns = idx1_cols
idx2.columns = idx2_cols

# %%
chinese_to_english = {
    "美国": "USA",
    "智利": "CHL",        # Chile
    "中国": "CHN",
    "哥伦比亚": "COL",    # Colombia
    "丹麦": "DNK",        # Denmark
    "希腊": "GRC",        # Greece
    "爱尔兰": "IRL",      # Ireland
    "日本": "JPN",
    "韩国": "KOR",        # South Korea
    "新西兰": "NZL",      # New Zealand
    "俄罗斯": "RUS",
    "财务压力": "FSI",     # TODO: Financial Stress Index - confirm country or worldwide
    "克罗地亚": "HRV",     # Croatia
    "巴基斯坦": "PAK",      
    "新加坡": "SGP"
}

idx1_cols = list(idx1.columns)
idx2_cols = list(idx2.columns)

for i, col in enumerate(idx1_cols):
    for chinese, english in chinese_to_english.items():
        if chinese in col:
            idx1_cols[i] = idx1_cols[i].replace(chinese, english)

for i, col in enumerate(idx2_cols):
    for chinese, english in chinese_to_english.items():
        if chinese in col:
            idx2_cols[i] = idx2_cols[i].replace(chinese, english)

idx1.columns = idx1_cols
idx2.columns = idx2_cols

# %%
period1_non_english_cols = {(i, col): [c for c in col if ord(c) > 127] for i, col in enumerate(idx1.columns) if not col.isascii()}
period2_non_english_cols = {(i, col): [c for c in col if ord(c) > 127] for i, col in enumerate(idx2.columns) if not col.isascii()}
display(period1_non_english_cols)
display(period2_non_english_cols)

assert len(period1_non_english_cols) == 0
assert len(period2_non_english_cols) == 0
# Out:
# {}
# {}

# %%
bdi1["Period"] = 1
bdi2["Period"] = 2

idx1["Period"] = 1
idx2["Period"] = 2

# %%
bdi = pd.concat([bdi1, bdi2])
idx = pd.concat([idx1, idx2])

bdi.index.name = "Time"
idx.index.name = "Time"

# %%
bdi
# Out:
#                    BDI  Period
# Time
# 2001-11-30   855.22727       1
# 2001-12-31   870.17647       1
# 2002-01-31   931.31818       1
# 2002-02-28  1365.39130       1
# 2002-03-31  1460.42857       1
# ...                ...     ...
# 2022-08-31  2943.04762       2
# 2022-09-30  2389.45000       2
# 2022-10-31  2076.95238       2
# 2022-11-30  1411.95455       2
# 2022-12-31  1487.14286       2
#
# [254 rows x 2 columns]

# %%
idx
# Out:
#             GEPU_current    GEPU_ppp  USA-Three_Component_Index  \
# Time
# 2001-11-30    126.150648  121.680190                        131
# 2001-12-31    107.734812  104.203253                        117
# 2002-01-31    106.974245  105.715560                        117
# 2002-02-28    117.630213  118.443801                        112
# 2002-03-31    122.379655  117.279174                        123
# ...                  ...         ...                        ...
# 2022-08-31    290.452395  301.851162                        168
# 2022-09-30    274.722090  292.320462                        146
# 2022-10-31    315.962071  326.803119                        187
# 2022-11-30    256.913949  262.792255                        163
# 2022-12-31    280.669847  289.610062                        174
#
#             USA-News_Based_Policy_Uncert_Index  \
# Time
# 2001-11-30                                 172
# 2001-12-31                                 150
# ...

# %%
path = "data/cleaned"
bdi.to_csv(f"{path}/BDI.csv")
idx.to_csv(f"{path}/Uncertainty_Indices.csv")

# %%
from ydata_profiling import ProfileReport

# Slightly overkill but lazy way to get kurtosis/skewness :) 
bdi1_stats = ProfileReport(bdi1)
bdi2_stats = ProfileReport(bdi2)

bdi1_stats
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-10-12 22:07:03.128830&quot; name=date&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
bdi2_stats
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-10-12 22:07:12.942782&quot; name=date&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
bdi["BDI"].plot(marker='o', alpha=0.7, figsize=(8, 6), title="BDI");

# %%
fig, ax = plt.subplots();
bdi1["BDI"].hist(bins=30, alpha=0.7, color="tab:blue", ax=ax, label="period I");
bdi2["BDI"].hist(bins=30, alpha=0.7, color="tab:red", ax=ax, label="period II");
ax.legend();

# %% [markdown]
# Big positive skew on both periods from the historgrams. Log transforms should help deal with this - doesn't seem like the target was transformed in the paper.

# %%
fig, ax = plt.subplots();
np.log(bdi1["BDI"]).hist(bins=30, alpha=0.7, color="tab:blue", ax=ax, label="period I");
np.log(bdi2["BDI"]).hist(bins=30, alpha=0.7, color="tab:red", ax=ax, label="period II");
fig.suptitle("BDI log returns")
ax.legend();

# %%
fig, ax = plt.subplots();
np.log(bdi1).diff().hist(bins=30, alpha=0.7, color="tab:blue", ax=ax, label="period I");
np.log(bdi2).diff().hist(bins=30, alpha=0.7, color="tab:red", ax=ax, label="period II");
fig.suptitle("BDI log returns")
ax.legend();
# Out:
# /var/folders/_1/x45gcqk13td92ct_53v0nwtr0000gn/T/ipykernel_47641/3965923545.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   np.log(bdi1).diff().hist(bins=30, alpha=0.7, color="tab:blue", ax=ax, label="period I");
# /var/folders/_1/x45gcqk13td92ct_53v0nwtr0000gn/T/ipykernel_47641/3965923545.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   np.log(bdi2).diff().hist(bins=30, alpha=0.7, color="tab:red", ax=ax, label="period II");
# /var/folders/_1/x45gcqk13td92ct_53v0nwtr0000gn/T/ipykernel_47641/3965923545.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend();

# %%
# log returns most symmetric
print(bdi["BDI"].skew())
print(np.log(bdi["BDI"]).skew())
print(np.log(bdi["BDI"]).diff().skew())
# Out:
# 2.037842545779221
# 0.3600352234236727
# -0.05071860230312539

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import adfuller

targets = {"BDI": bdi["BDI"], "log": np.log(bdi["BDI"]), "Log return": np.log(bdi["BDI"]).diff().dropna()}

for name, series in targets.items(): 
    fig, ax = plt.subplots(1, 2)
    plot_acf(series.values, ax=ax[0])
    plot_pacf(series.values, ax=ax[1]);
    fig.suptitle(f"{name}, adf p-value = {adfuller(series.values)[1]:.3f}")
    fig.tight_layout()
    fig.show()
# Out:
# /var/folders/_1/x45gcqk13td92ct_53v0nwtr0000gn/T/ipykernel_47641/3987157957.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /var/folders/_1/x45gcqk13td92ct_53v0nwtr0000gn/T/ipykernel_47641/3987157957.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /var/folders/_1/x45gcqk13td92ct_53v0nwtr0000gn/T/ipykernel_47641/3987157957.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# From the acf/pcf plots and adf stats, we have clear evidence that BDI/log BDI are non-stationary, while the log-returns appear to be mostly stationary. We should definitely consider predicting the log-return as an alternative target. As expected, the strongest partial auto-correlation comes from the previous value (lag 1), so the martingale model should definitely be included as naive baseline.

# %%
fig, ax = plt.subplots()
for window in [3, 6, 9, 12]:
    z = (bdi["BDI"] - bdi["BDI"].rolling(window=window).mean()) / bdi["BDI"].rolling(window=window).std()
    z.dropna().plot(label=f"window = {window}", ax=ax, alpha=0.5);
    ax.legend()
fig.suptitle("Rolling-Z scores BDI");

# %%
fig, ax = plt.subplots()
for window in [3, 6, 9, 12]:
    z = (targets["Log return"] - targets["Log return"].rolling(window=window).mean()) / targets["Log return"].rolling(window=window).std()
    z.dropna().plot(label=f"window = {window}", ax=ax, alpha=0.5);
    ax.legend()
fig.suptitle("Rolling-Z scores Log-Return");

# %%
bdi["BDI"].rolling(window=6).mean().plot();

# %%
bdi["BDI"].rolling(window=6).std().plot()
# Out:
# <Axes: xlabel='Time'>

# %%
targets["Log return"].rolling(window=3).mean().plot()
# Out:
# <Axes: xlabel='Time'>

# %%
targets["Log return"].rolling(window=3).std().plot()
# Out:
# <Axes: xlabel='Time'>

# %%
targets["log"].rolling(window=3).mean().plot()
# Out:
# <Axes: xlabel='Time'>
