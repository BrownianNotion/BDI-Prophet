# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme()

# %%
bdi1 = pd.read_excel("data/Period I/BDI.xlsx")
bdi2 = pd.read_excel("data/Period II/BDI.xlsx")

idx1 = pd.read_excel("data/Period I/Uncertainty Indexes.xlsx") 
idx2 = pd.read_excel("data/Period II/Uncertain Indexes.xlsx")

# %%
bdi1
# Out:
#         Time         BDI
# 0    2001.11   855.22727
# 1    2001.11   870.17647
# 2    2002.10   931.31818
# 3    2002.20   959.55000
# 4    2002.30  1064.75000
# ..       ...         ...
# 118  2011.90  1840.40909
# 119  2011.10  2072.47619
# 120  2011.11  1835.31818
# 121  2011.12  1868.82353
# 122  2012.10  1039.38095
#
# [123 rows x 2 columns]

# %%
bdi2
# Out:
#         Time         BDI
# 0    2012.20   702.61905
# 1    2012.30   858.95455
# 2    2012.40  1020.52632
# 3    2012.50  1101.27273
# 4    2012.60   937.42105
# ..       ...         ...
# 126  2022.80  1411.95455
# 127  2022.90  1487.14286
# 128  2022.10  1813.85714
# 129  2022.11  1298.95455
# 130  2022.12  1453.41176
#
# [131 rows x 2 columns]

# %%
idx1
# Out:
#         Time  GEPU_current    GEPU_ppp  美国-Three_Component_Index  \
# 0    2001.11    126.150648  121.680190                       131
# 1    2001.11    107.734812  104.203253                       117
# 2    2002.10    106.974245  105.715560                       117
# 3    2002.20     89.900054   88.641668                        88
# 4    2002.30     78.781740   79.094478                        83
# ..       ...           ...         ...                       ...
# 118  2011.90    190.957718  187.993301                       205
# 119  2011.10    165.130505  170.269630                       160
# 120  2011.11    197.574134  204.322067                       166
# 121  2011.12    181.425466  190.839742                       189
# 122  2012.10    160.907847  167.537829                       178
#
#      美国-News_Based_Policy_Uncert_Index  美国-1. Economic Policy Uncertainty  \
# 0                                  172                         153.501517
# ...

# %%
idx2
# Out:
#         Time  GEPU_current    GEPU_ppp  美国-Three_Component_Index  \
# 0    2012.20    141.622551  147.885446                       150
# 1    2012.30    134.292361  148.068999                       138
# 2    2012.40    126.483872  130.266071                       137
# 3    2012.50    159.535464  164.349088                       159
# 4    2012.60    188.157861  194.856394                       195
# ..       ...           ...         ...                       ...
# 126  2022.80    256.913949  262.792255                       163
# 127  2022.90    280.669847  289.610062                       174
# 128  2022.10    299.774458  307.753749                       177
# 129  2022.11    331.335811  347.730650                       172
# 130  2022.12    260.434961  277.400806                       136
#
#      美国-News_Based_Policy_Uncert_Index  美国-1. Economic Policy Uncertainty  \
# 0                                  119                         100.170604
# ...

# %%
bdi1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    123 non-null    float64
#  1   BDI     123 non-null    float64
# dtypes: float64(2)
# memory usage: 2.1 KB

# %%
bdi2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    131 non-null    float64
#  1   BDI     131 non-null    float64
# dtypes: float64(2)
# memory usage: 2.2 KB

# %%
idx1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Columns: 378 entries, Time to GPRHC_ZAF
# dtypes: float64(371), int64(7)
# memory usage: 363.4 KB

# %%
idx2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Columns: 446 entries, Time to GPRHC_ZAF
# dtypes: float64(441), int64(5)
# memory usage: 456.6 KB

# %%
bdi1 = bdi1.set_index("Time").sort_index()
bdi2 = bdi2.set_index("Time").sort_index()

# %%
bdi1.plot(marker='o', alpha=0.7, figsize=(8, 6), title="period I");

# %%
bdi2.plot(marker='o', alpha=0.7, figsize=(8, 6), title="period II");

# %%
bdi1.hist(bins=30, alpha=0.7);

# %%
np.log(bdi1).hist(bins=30, alpha=0.7);
